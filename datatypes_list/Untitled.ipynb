# %%
l1=[1,2,3]
l2=[4,5,6]
l2.extend(l1)

# %%
l2
# Out:
# [4, 5, 6, 1, 2, 3]

# %%
import random
print(random.choice(l2))
# Out:
# 5

# %%
list1 = [10, 10, 0, 0, 10]
list2 = [10, 10, 10, 0, 0]
list3 = [1, 10, 10, 0, 0]
print(' '.join(map(str, list2))) #in ' '.join(map(str, list1 * 2)))
# Out:
# 10 10 10 0 0

# %%
print(' '.join(map(str, list1*2)))
# Out:
# 10 10 0 0 10 10 10 0 0 10

# %%
l=[1,4,3,6,2,5,9,7,0,8]
print(sorted(l)[-2])
# Out:
# 1

# %%
range=250
l=[20,30,405,60,70,452,251]
print(len([i for i in l if i <range]))
# Out:
# 4

# %%
from itertools import permutations, combinations, combinations_with_replacement
l=[20,30,405,60,70,452,251]
len_l=len(l)
for i in range(len_l+1):
    print('***************')
    print(list(permutations(l,i)))
    print('***************')
# Out:
# ***************
# [()]
# ***************
# ***************
# [(20,), (30,), (405,), (60,), (70,), (452,), (251,)]
# ***************
# ***************
# [(20, 30), (20, 405), (20, 60), (20, 70), (20, 452), (20, 251), (30, 20), (30, 405), (30, 60), (30, 70), (30, 452), (30, 251), (405, 20), (405, 30), (405, 60), (405, 70), (405, 452), (405, 251), (60, 20), (60, 30), (60, 405), (60, 70), (60, 452), (60, 251), (70, 20), (70, 30), (70, 405), (70, 60), (70, 452), (70, 251), (452, 20), (452, 30), (452, 405), (452, 60), (452, 70), (452, 251), (251, 20), (251, 30), (251, 405), (251, 60), (251, 70), (251, 452)]
# ***************
# ***************
# ...

# %%
len(l)
# Out:
# 7

# %%
for ele in range(7):
    print(ele)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
print(range(7))
# Out:
# range(0, 7)

# %%
print('Hi')
# Out:
# Hi
